# %% [markdown]
# ### YOLOv8 Segmentation Model Loading

# %%
from ultralytics import YOLO
model=YOLO('yolo11n-seg.pt')

# %% [markdown]
# ### YOLOv8 Segmentation Training for Lane Detection

# %%
# !yolo segment train \
  data="/content/drive/MyDrive/Lane Detection -Segmentation-.v7i.yolov11/data.yaml" \
  model=yolo11n-seg.pt \
  epochs=200 \
  patience=30 \
  imgsz=640 \
  name="lane-seg"
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ### YOLOv8 Lane Segmentation Model Validation

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/segment/lane-seg/weights/best.pt')
model.val()
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-seg summary (fused): 113 layers, 2,835,348 parameters, 0 gradients, 9.6 GFLOPs
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 16.9±7.4 MB/s, size: 34.0 KB)
# val: Scanning /content/drive/MyDrive/Lane Detection -Segmentation-.v7i.yolov11/valid/labels.cache... 318 images, 21 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 318/318 76.3Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 2.9it/s 7.0s
#                    all        318        841      0.895      0.854      0.909      0.749      0.882       0.83      0.887      0.555
# Left Boundary -Dashed-        158        356      0.934      0.759      0.888      0.631      0.933      0.741      0.877      0.464
# ...

# %% [markdown]
# ### Model Loading for Inference

# %%
infr_model=YOLO('/content/runs/segment/lane-seg/weights/best.pt')

# %% [markdown]
# ### Inference on Test Images

# %%
results = infr_model("/content/drive/My Drive/Lane Detection -Segmentation-.v7i.yolov11/test/images",conf=0.6)
results[34].show()
# Out:
# image 1/151 /content/drive/My Drive/Lane Detection -Segmentation-.v7i.yolov11/test/images/00010_resized_png.rf.1ecc60c3cdb26f1564858c04a17fd93d.jpg: 384x640 (no detections), 11.7ms
# image 2/151 /content/drive/My Drive/Lane Detection -Segmentation-.v7i.yolov11/test/images/0003-2-_resized_png.rf.cf434bea20c90f042e58457e3cac1c72.jpg: 384x640 (no detections), 9.0ms
# image 3/151 /content/drive/My Drive/Lane Detection -Segmentation-.v7i.yolov11/test/images/0006_resized_png.rf.9b8dcae6da39e317ab80700ebde66307.jpg: 384x640 (no detections), 10.1ms
# image 4/151 /content/drive/My Drive/Lane Detection -Segmentation-.v7i.yolov11/test/images/0008_resized_png.rf.47281428cb424780b39012430fe5aefd.jpg: 384x640 (no detections), 10.1ms
# image 5/151 /content/drive/My Drive/Lane Detection -Segmentation-.v7i.yolov11/test/images/0014_resized_png.rf.c69f1b6a34b41d116bcfe699840fdd42.jpg: 384x640 (no detections), 9.0ms
# ...

# %% [markdown]
# ### Display Lane Segmentation Result Image

# %%
from IPython.display import Image, display

display(Image("/content/drive/My Drive/lane-seg/results.png"))
